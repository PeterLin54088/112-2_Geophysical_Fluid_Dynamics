# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt

# %%
pwd()
# Out:
# '/home/b08209033/112-2_Geophysical_Fluid_Dynamics/Barotropic model'

# %%
file = h5py.File("snapshots/snapshots_s1/snapshots_s1_p0.h5", 'r')

# %%
psi = file["tasks"]["psi"][:]
x = file["scales"]["x"]["1.0"][:]
y = file["scales"]["y"]["1.0"][:]
t = file["scales"]["sim_time"][:]

# %%
plt.contourf(psi[-1])
